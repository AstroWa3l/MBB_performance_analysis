# %%
#Importing packages
import math as m
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

pd.options.mode.chained_assignment = None  # default='warn'


pd.options.display.max_columns = 60
pd.options.display.max_rows = 99

# %%
df1 = pd.read_excel('OffvsMan_Zone19_20.xlsx', sheet_name='playtypesVsZone')

# %%
df1
# Out:
#                          Play Types % Time Poss Points    PPP  Rank  \
# 0                           Spot Up  0.655  235    276  1.174  0.84
# 1                               Cut  0.139   50     68   1.36  0.92
# 2                           Post-Up  0.047   17     11  0.647   0.3
# 3    Offensive Rebounds (put backs)  0.033   12     15   1.25  0.74
# 4                  P&R Ball Handler  0.031   11      8  0.727  0.49
# 5                      P&R Roll Man  0.017    6      4  0.667     -
# 6                         Isolation  0.014    5      4    0.8     -
# 7                          Hand Off  0.014    5      0      0     -
# 8                        Off Screen  0.006    2      6      3     -
# 9                        Transition      -    -      -      -     -
# 10                    Miscellaneous  0.045   16      5  0.312  0.65
#
#            Rating  FGm FGM  FGA    FG%   aFG%    %TO    %FT    %SF %Score
# 0       Excellent  115  91  206  0.442  0.629  0.085  0.047  0.038  0.426
# 1       Excellent    9  26   35  0.743  0.743   0.12   0.22    0.2    0.7
# 2   Below Average    7   4   11  0.364  0.364  0.235  0.118  0.118  0.353
# 3       Very Good    4   7   11  0.636  0.636  0.083  0.083  0.083  0.583
# 4         Average    3   3    6    0.5  0.583  0.364  0.091      0  0.364
# 5               -    2   2    4    0.5    0.5  0.167  0.167  0.167  0.333
# 6               -    1   1    2    0.5    0.5    0.4    0.2    0.2    0.4
# 7               -    4   0    4      0      0    0.2      0      0      0
# 8               -    0   2    2      1    1.5      0      0      0      1
# 9               -    -   -    -      -      -      -      -      -      -
# 10      Very Good    1   1    2    0.5   0.75  0.813  0.063      0  0.125

# %%
# I am going to go ahead and drop the "Transition" row due to no recorded data. 
df1 = df1.drop([9])

# %%
df1['PPer100P'] = 100*df1['PPP']

# %%
df1
# Out:
#                          Play Types % Time Poss Points    PPP  Rank  \
# 0                           Spot Up  0.655  235    276  1.174  0.84
# 1                               Cut  0.139   50     68   1.36  0.92
# 2                           Post-Up  0.047   17     11  0.647   0.3
# 3    Offensive Rebounds (put backs)  0.033   12     15   1.25  0.74
# 4                  P&R Ball Handler  0.031   11      8  0.727  0.49
# 5                      P&R Roll Man  0.017    6      4  0.667     -
# 6                         Isolation  0.014    5      4    0.8     -
# 7                          Hand Off  0.014    5      0      0     -
# 8                        Off Screen  0.006    2      6      3     -
# 10                    Miscellaneous  0.045   16      5  0.312  0.65
#
#            Rating  FGm FGM  FGA    FG%   aFG%    %TO    %FT    %SF %Score  \
# 0       Excellent  115  91  206  0.442  0.629  0.085  0.047  0.038  0.426
# 1       Excellent    9  26   35  0.743  0.743   0.12   0.22    0.2    0.7
# 2   Below Average    7   4   11  0.364  0.364  0.235  0.118  0.118  0.353
# 3       Very Good    4   7   11  0.636  0.636  0.083  0.083  0.083  0.583
# 4         Average    3   3    6    0.5  0.583  0.364  0.091      0  0.364
# 5               -    2   2    4    0.5    0.5  0.167  0.167  0.167  0.333
# 6               -    1   1    2    0.5    0.5    0.4    0.2    0.2    0.4
# 7               -    4   0    4      0      0    0.2      0      0      0
# 8               -    0   2    2      1    1.5      0      0      0      1
# 10      Very Good    1   1    2    0.5   0.75  0.813  0.063      0  0.125
#
#    PPer100P
# 0     117.4
# 1       136
# 2      64.7
# 3       125
# 4      72.7
# 5      66.7
# 6        80
# 7         0
# 8       300
# 10     31.2

# %%
ax = df1.plot(x='Play Types', y=['Poss','Points'], kind="bar",width=.75,color=['Gold','Blue',],figsize=(15,7))
plt.ylabel('Total'),plt.title("Performance vs Zone Defesne by Play Type\n2019-2020 Season")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+.04, i.get_height()+5, \
            str(round((i.get_height()), 2)), fontsize=12, color='Black',
                rotation=0,weight='bold')
plt.savefig('Performance_Zone_Def_Play_Type.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
ax = df1.plot(x='Play Types', y=['PPP'], kind="bar",width=.75,color=['Blue'],figsize=(15,7))
plt.ylabel('Points Per Possesion'),plt.title("Performance vs Zone Defesne by Play Type\n2019-2020 Season")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+0.15, i.get_height()+0.015, \
            str(round((i.get_height()), 2)), fontsize=12, color='Black',
                rotation=0)
# plt.savefig('Performance_Zone_Def_Play_Type.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
df2 = pd.read_excel('OffvsMan_Zone19_20.xlsx', sheet_name='playersVsZone')
df2
# Out:
#                  Overall  % Time  Poss  Points    PPP  Rank     Rating  FGm  \
# 0   UC San Diego Tritons   1.000   359     397  1.106   0.9  Excellent  146
# 1   #14 Christian Oshita   0.228    82     107  1.305   0.9  Excellent   33
# 2      #2 Tyrell Roberts   0.203    73      92  1.260  0.88  Excellent   31
# 3         #3 Gabe Hadley   0.134    48      38  0.792  0.34    Average   26
# 4      #11 Scott Everman   0.128    46      45  0.978  0.57       Good   22
# 5      #32 Mickey Howell   0.084    30      29  0.967  0.56       Good   10
# 6      #5 Marek Sullivan   0.081    29      40  1.379  0.93  Excellent    5
# 7       #44 Chris Hansen   0.025     9      12  1.333     -          -    1
# 8       #25 Martin Tombe   0.019     7      13  1.857     -          -    2
# 9     #23 Kadeen Rasheed   0.017     6       2  0.333     -          -    4
# 10        #1 Hugh Baxter   0.017     6       5  0.833     -          -    2
# 11   #10 Connor Peterson   0.014     5       3  0.600     -          -    1
# 12      #12 Justin Pratt   0.014     5       3  0.600     -          -    3
# 13       #24 John Diener   0.014     5       6  1.200     -          -    3
# 14      #33 Trace Ramsey   0.014     5       2  0.400     -          -    2
# 15      #0 Lunden Taylor   0.008     3       0  0.000     -          -    1
#
#     FGM  FGA    FG%   aFG%    %TO    %FT    %SF  %Score
# 0   137  283  0.484  0.627  0.145  0.081  0.067   0.446
# 1    37   70  0.529  0.679  0.049  0.110  0.098   0.537
# 2    30   61  0.492  0.705  0.123  0.041  0.041   0.452
# 3    13   39  0.333  0.474  0.188  0.021  0.021   0.271
# 4    15   37  0.405  0.486  0.087  0.130  0.087   0.435
# 5     9   19  0.474  0.684  0.267  0.100  0.067   0.400
# 6    17   22  0.773  0.818  0.172  0.103  0.069   0.655
# 7     5    6  0.833  0.833  0.222  0.111  0.111   0.667
# 8     4    6  0.667  0.917  0.000  0.143  0.143   0.714
# 9     1    5  0.200  0.200  0.167  0.000  0.000   0.167
# 10    1    3  0.333  0.500  0.333  0.167  0.167   0.333
# 11    1    2  0.500  0.750  0.600  0.000  0.000   0.200
# 12    1    4  0.250  0.250  0.200  0.200  0.200   0.200
# 13    2    5  0.400  0.600  0.000  0.000  0.000   0.400
# 14    1    3  0.333  0.333  0.400  0.000  0.000   0.200
# 15    0    1  0.000  0.000  0.667  0.000  0.000   0.000

# %%
df3 = df2.drop([0,7,8,9,10,11,12,13,14,15])

# %%
ax = df3.plot(x='Overall', y=['Poss','Points'], kind="bar",width=.75,color=['Gold','Blue',],figsize=(15,7))
plt.ylabel('Number of'),plt.title("Overall Performance vs Zone Defesne\n2019-2020 Season")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+.15, i.get_height()+1, \
            str(round((i.get_height()), 2)), fontsize=11, color='Black',
                rotation=0)
plt.savefig('Overall_Performance_vs_Zone_Def.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
ax = df3.plot(x='Overall', y=['PPP'], kind="bar",width=.75,color=['blue'],figsize=(15,7))
plt.ylabel('Points Per Possesion'),plt.title("Player Performance vs Zone Defesne\n2019-2020 Season"),plt.xticks(rotation=65)
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+0.2, i.get_height()-0.1, \
            str(round((i.get_height()), 2)), fontsize=14, color='Gold',
                rotation=0,weight='bold')
plt.savefig('main_rotation_ZoneDef_performance.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
df4 = pd.read_excel('OffvsMan_Zone19_20.xlsx', sheet_name='playersVsMan')
df4
# Out:
#                  Overall  % Time  Poss  Points    PPP  Rank         Rating  \
# 0   UC San Diego Tritons   1.000  1299    1437  1.106     1      Excellent
# 1      #2 Tyrell Roberts   0.219   285     306  1.074  0.88      Excellent
# 2   #14 Christian Oshita   0.182   237     272  1.148  0.95      Excellent
# 3      #11 Scott Everman   0.120   156     190  1.218  0.98      Excellent
# 4      #32 Mickey Howell   0.103   134     130  0.970  0.72      Very Good
# 5         #3 Gabe Hadley   0.089   115     145  1.261  0.99      Excellent
# 6      #5 Marek Sullivan   0.085   110     129  1.173  0.96      Excellent
# 7       #44 Chris Hansen   0.080   104     139  1.337     1      Excellent
# 8         #1 Hugh Baxter   0.028    36      24  0.667  0.15  Below Average
# 9       #25 Martin Tombe   0.022    28      29  1.036  0.83      Excellent
# 10    #23 Kadeen Rasheed   0.016    21      24  1.143  0.94      Excellent
# 11   #10 Connor Peterson   0.015    20      11  0.550  0.07           Poor
# 12      #12 Justin Pratt   0.012    16      16  1.000  0.78      Very Good
# 13      #33 Trace Ramsey   0.010    13      10  0.769  0.28  Below Average
# 14      #0 Lunden Taylor   0.006     8       6  0.750     -              -
# 15    #15 Jeremy Johnson   0.006     8       2  0.250     -              -
# 16       #24 John Diener   0.006     8       4  0.500     -              -
#
#     FGm  FGM   FGA    FG%   aFG%    %TO    %FT    %SF  %Score
# 0   501  510  1011  0.504  0.602  0.121  0.119  0.075   0.487
# 1   129  106   235  0.451  0.549  0.088  0.098  0.056   0.456
# 2    95   93   188  0.495  0.620  0.097  0.122  0.068   0.494
# 3    61   74   135  0.548  0.641  0.077  0.077  0.064   0.532
# 4    30   43    73  0.589  0.678  0.313  0.179  0.119   0.463
# 5    51   51   102  0.500  0.657  0.078  0.061  0.052   0.478
# 6    32   53    85  0.624  0.647  0.109  0.136  0.100   0.591
# 7    38   50    88  0.568  0.670  0.058  0.115  0.087   0.577
# 8    18    9    27  0.333  0.352  0.139  0.111  0.056   0.333
# 9    11    6    17  0.353  0.500  0.143  0.250  0.107   0.464
# 10    6    8    14  0.571  0.750  0.238  0.143  0.095   0.476
# 11    7    4    11  0.364  0.364  0.250  0.250  0.150   0.250
# 12    6    7    13  0.538  0.577  0.125  0.125  0.125   0.500
# 13    5    3     8  0.375  0.375  0.154  0.231  0.077   0.385
# 14    2    1     3  0.333  0.333  0.250  0.375  0.125   0.500
# 15    5    1     6  0.167  0.167  0.250  0.000  0.000   0.125
# 16    5    1     6  0.167  0.167  0.125  0.125  0.000   0.250

# %%
df4 = df4.drop([0,7,10,11,12,13,14,15,16])

# %%
ax = df4.plot(x='Overall', y=['Poss','Points'], kind="bar",width=.75,color=['Gold','Blue',],figsize=(15,7))
plt.ylabel('Totals'),plt.title("Players Performance vs Man Defesne\n2019-2020 Season"),plt.xticks(rotation=60)
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+.04, i.get_height()+5, \
            str(round((i.get_height()), 2)), fontsize=11, color='Black',
                rotation=0)
plt.savefig('Rotation Players Performance vs Man Defesne.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
df6 = pd.read_excel('OffvsMan_Zone19_20.xlsx', sheet_name='playtypesVsMan')

# %%
ax = df6.plot(x='Play Types', y=['Poss','Points'], kind="bar",width=.75,color=['Gold','Blue',],figsize=(15,7))
plt.ylabel('Totals'),plt.title("Players Performance vs Man Defesne\n2019-2020 Season"),plt.xticks(rotation=60)
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+.04, i.get_height()+5, \
            str(round((i.get_height()), 2)), fontsize=11, color='Black',
                rotation=0)

# %%
ax = df4.plot(x='Overall', y=['PPP'], kind="bar",width=.75,color=['blue'],figsize=(15,7))
plt.ylabel('Points Per Possesion'),plt.title("Player Performance vs Man Defesne\n2019-2020 Season"),plt.xticks(rotation=65)
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+0.2, i.get_height()-0.1, \
            str(round((i.get_height()), 2)), fontsize=14, color='Gold',
                rotation=0,weight='bold')
# plt.savefig('main_rotation_ZoneDef_performance.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
df5 = pd.read_excel('OffvsMan_Zone19_20.xlsx', sheet_name='TeamVsZoneandMan')

# %%
ax = df5.plot(x='Overall', y=['Poss','Points'], kind="bar",width=.75,color=['Gold','Blue',],figsize=(12,6))
plt.ylabel('Totals'),plt.title("Team Performance vs Defesne\n2019-2020 Season"),plt.xticks(rotation=0)
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+0.09, i.get_height()-120, \
            str(round((i.get_height()), 2)), fontsize=14, color='Black',
                rotation=0,weight=None)

# %%
ax = df5.plot(x='Overall', y=['PPP'], kind="bar",width=.75,color=['Gold'],figsize=(12,6))
plt.ylabel('Totals'),plt.title("Team Performance vs Defesne\n2019-2020 Season"),plt.xticks(rotation=0)
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for i in ax.patches:
    ax.text(i.get_x()+0.3, i.get_height()-0.1, \
            str(round((i.get_height()), 2)), fontsize=14, color='darkblue',
                rotation=0,weight=None)
