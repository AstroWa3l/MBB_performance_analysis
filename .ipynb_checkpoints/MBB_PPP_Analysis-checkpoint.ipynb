# %%
#Importing packages
import math as m
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

pd.options.mode.chained_assignment = None  # default='warn'


pd.options.display.max_columns = 60
pd.options.display.max_rows = 99

# %%
df_17_18_opp = pd.read_excel('PPP_Analysis.xlsx', sheet_name='17_18PerOpp')
df_17_18_opp
# Out:
#              Opponent   OPP_APPP  UCSD_APPP  Meetings  Season_APPP_Conf  \
# 0                Chico  0.736667   0.980000         3             0.913
# 1   CalStateStanislaus  0.953333   1.006667         3             0.913
# 2           CalStateLA  0.795000   0.990000         2             0.883
# 3     CalStateDomHills  1.005000   0.935000         2             0.885
# 4        HumboldtState  0.900000   1.200000         2             0.849
# 5      CSSanBernardino  0.935000   1.055000         2             0.905
# 6        CalPolyPomona  1.080000   0.950000         1             0.891
# 7       SanFranciscoSt  0.820000   0.850000         2             0.920
# 8          SonomaState  0.915000   0.985000         2             0.886
# 9         Cal State SM  0.915000   1.060000         2             0.993
# 10     CalStateEastBay  0.930000   1.070000         1             0.857
# 11          CSMonterey  0.990000   1.065000         2             0.845
# ...

# %%
df_17_18 = pd.read_excel('PPP_Analysis.xlsx', sheet_name='17_18_Season')

# %%
df_18_19 = pd.read_excel('PPP_Analysis.xlsx', sheet_name='18_19_Season')
df_18_19_opp = pd.read_excel('PPP_Analysis.xlsx', sheet_name='18_19PerOpp')

# %%
df_19_20 = pd.read_excel('PPP_Analysis.xlsx', sheet_name='19_20_Season')
df_19_20_opp = pd.read_excel('PPP_Analysis.xlsx', sheet_name='19_20PerOpp')

# %%
df_17_18_opp['OPP_APPP-SeasonAPPP']= (df_17_18_opp['OPP_APPP'] - df_17_18_opp['Season_APPP_Conf'])*100
df_17_18_opp['Net_PPP'] = (df_17_18_opp['UCSD_APPP_Adj'] - df_17_18_opp['OPP_APPP_Adj'])
df_17_18['Net_PPP'] = (df_17_18['HomeTeamPPP'] - df_17_18['AwayTeamPPP'])

# %%
df_17_18_opp['UCSD_APPP-SeasonAPPP']= (df_17_18_opp['UCSD_APPP'] - df_17_18['UCSD AVG PPP'][0])*100
df_17_18_opp
# Out:
#              Opponent   OPP_APPP  UCSD_APPP  Meetings  Season_APPP_Conf  \
# 0                Chico  0.736667   0.980000         3             0.913
# 1   CalStateStanislaus  0.953333   1.006667         3             0.913
# 2           CalStateLA  0.795000   0.990000         2             0.883
# 3     CalStateDomHills  1.005000   0.935000         2             0.885
# 4        HumboldtState  0.900000   1.200000         2             0.849
# 5      CSSanBernardino  0.935000   1.055000         2             0.905
# 6        CalPolyPomona  1.080000   0.950000         1             0.891
# 7       SanFranciscoSt  0.820000   0.850000         2             0.920
# 8          SonomaState  0.915000   0.985000         2             0.886
# 9         Cal State SM  0.915000   1.060000         2             0.993
# 10     CalStateEastBay  0.930000   1.070000         1             0.857
# 11          CSMonterey  0.990000   1.065000         2             0.845
# ...

# %%
df_18_19_opp['OPP_APPP-SeasonAPPP']= (df_18_19_opp['OPP_APPP'] - df_18_19_opp['Season_APPP_Conf'])*100
df_18_19_opp['Net_PPP'] = (df_18_19_opp['OPP_APPP_Adj'] - df_18_19_opp['UCSD_APPP_Adj'])

# %%
df_18_19_opp['UCSD_APPP-SeasonAPPP']= (df_18_19_opp['UCSD_APPP'] - df_18_19['UCSD AVG PPP'][0])*100
df_18_19_opp
# Out:
#              Opponent   OPP_APPP  UCSD_APPP  Meetings  Season_APPP_Conf  \
# 0                Chico  0.840000   1.075000         2             0.872
# 1   CalStateStanislaus  0.890000   1.110000         2             0.899
# 2           CalStateLA  0.975000   0.770000         2             0.850
# 3     CalStateDomHills  0.885000   1.115000         2             0.914
# 4        HumboldtState  0.825000   1.035000         2             0.841
# 5      CSSanBernardino  0.823333   1.146667         3             0.863
# 6        CalPolyPomona  0.786667   0.880000         3             0.870
# 7       SanFranciscoSt  0.915000   1.165000         2             0.904
# 8          SonomaState  0.960000   1.080000         2             0.862
# 9         Cal State SM  0.845000   0.980000         2             0.817
# 10     CalStateEastBay  0.885000   1.040000         2             0.910
# 11          CSMonterey  0.900000   1.365000         2             0.836
# ...

# %%
df_19_20_opp['OPP_APPP-SeasonAPPP']= (df_19_20_opp['OPP_APPP'] - df_19_20_opp['Season_APPP_Conf'])*100
df_19_20_opp['Net_PPP'] = (df_19_20_opp['OPP_APPP_Adj'] - df_19_20_opp['UCSD_APPP_Adj'])
df_19_20_opp['UCSD_APPP-SeasonAPPP']= (df_19_20_opp['UCSD_APPP'] - df_19_20['UCSD Season PPP'][0])*100
df_19_20_opp
# Out:
#              Opponent   OPP_APPP  UCSD_APPP  Meetings  Season_APPP_Conf  \
# 0                Chico      1.12       0.94         1             0.998
# 1   CalStateStanislaus      0.75       1.03         1             0.869
# 2     CalStateDomHills      0.90       1.33         1             0.882
# 3      CSSanBernardino      0.87       1.06         1             0.903
# 4        CalPolyPomona      0.78       0.87         1             0.985
# 5          SonomaState      0.97       1.22         1             0.840
# 6         Cal State SM      0.72       1.07         1             0.906
# 7      CalStateEastBay      0.92       1.00         1             0.867
# 8           CSMonterey      0.89       1.22         1             0.888
# 9      SimonFraserClan      0.93       1.12         1             0.934
# 10  WesternWashington       0.83       1.03         1             0.980
# 11        SaintMartins      0.71       1.13         1             0.934
# ...

# %%
plt.figure(figsize=(80,80))
df_17_18_opp.plot(x="Opponent ", y=["OPP_APPP_Adj","UCSD_APPP_Adj","Net_PPP"], kind="bar",width=.75)
plt.xlabel("Opponent"),plt.ylabel('values'),plt.title("")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
# plt.subplot(x='Last',y=["AST","TS%","TPo%"])
# plt.savefig('TEST_.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
#df_17_18['Net_PPP']=df_17_18['Net_PPP']*100
df_17_18_opp['Above our AVGPPP']= df_17_18_opp['UCSD_APPP']>df_17_18['UCSD AVG PPP'][0]
df_17_18_opp
# Out:
#              Opponent   OPP_APPP  UCSD_APPP  Meetings  Season_APPP_Conf  \
# 0                Chico  0.736667   0.980000         3             0.913
# 1   CalStateStanislaus  0.953333   1.006667         3             0.913
# 2           CalStateLA  0.795000   0.990000         2             0.883
# 3     CalStateDomHills  1.005000   0.935000         2             0.885
# 4        HumboldtState  0.900000   1.200000         2             0.849
# 5      CSSanBernardino  0.935000   1.055000         2             0.905
# 6        CalPolyPomona  1.080000   0.950000         1             0.891
# 7       SanFranciscoSt  0.820000   0.850000         2             0.920
# 8          SonomaState  0.915000   0.985000         2             0.886
# 9         Cal State SM  0.915000   1.060000         2             0.993
# 10     CalStateEastBay  0.930000   1.070000         1             0.857
# 11          CSMonterey  0.990000   1.065000         2             0.845
# ...

# %%
pearsoncorr=df_17_18_opp.corr(method='pearson')

# %%
# plt.figure(figsize=(16, 16))
# sns.heatmap(pearsoncorr, 
#             xticklabels=pearsoncorr.columns,
#             yticklabels=pearsoncorr.columns,
#             cmap='RdBu_r',
#             annot=True,
#             linewidth=0.5)
# b, t = plt.ylim() # discover the values for bottom and top
# b += 0.5 # Add 0.5 to the bottom
# t -= 0.5 # Subtract 0.5 from the top
# plt.ylim(b, t) # update the ylim(bottom, top) values
# plt.show() # ta-da!

# %%
# pearsoncorr_seas=df_17_18.corr(method='pearson')

# %%
# plt.figure(figsize=(20, 16))
# sns.heatmap(pearsoncorr_seas, 
#             xticklabels=pearsoncorr_seas.columns,
#             yticklabels=pearsoncorr_seas.columns,
#             cmap='RdBu_r',
#             annot=True,
#             linewidth=0.5)
# b, t = plt.ylim() # discover the values for bottom and top
# b += 0.5 # Add 0.5 to the bottom
# t -= 0.5 # Subtract 0.5 from the top
# plt.ylim(b, t) # update the ylim(bottom, top) values
# plt.show() # ta-da!

# %%
# df_18_19_opp['UCSD_APPP']>df_18_19['UCSD AVG PPP'][0]

# %%
# plt.figure(figsize=(80,80))
# df_19_20_opp.plot(x="Opponent ", y=["OPP_APPP_Adj","UCSD_APPP_Adj"], kind="bar",width=.8)
# plt.xlabel("Opponent"),plt.ylabel('Pts Per 100 Pos'),plt.title("")
# lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
# # plt.subplot(x='Last',y=["AST","TS%","TPo%"])
# plt.savefig('PPP_PerOpp2019.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
df_19_20
# Out:
#                   Date                      Game Name  AwayTeamPPP  \
# 0  2020-02-01 20:00:00  CalStateStanislaus@UCSanDiego         92.4
# 1  2020-01-30 18:30:00       HumboldtState@UCSanDiego         91.3
# 2  2020-01-25 14:00:00         UCSanDiego@SonomaState        133.3
# 3  2020-01-23 18:30:00      UCSanDiego@SanFranciscoSt        119.1
# 4  2020-01-18 18:30:00     CSSanBernardino@UCSanDiego         81.9
# 5  2020-01-16 18:30:00       CalPolyPomona@UCSanDiego         95.0
# 6  2020-01-11 18:30:00       UCSanDiego@HumboldtState        132.3
# 7  2020-01-09 18:30:00  UCSanDiego@CalStateStanislaus        107.2
# 8  2020-01-04 18:30:00     CalStateEastBay@UCSanDiego        101.4
# 9  2020-01-02 18:30:00          CSMonterey@UCSanDiego        102.9
# 10 2020-12-22 14:30:00       UCSanDiego@CalPolyPomona         95.7
# 11 2020-12-19 18:30:00         SonomaState@UCSanDiego        109.5
# 12 2020-12-17 18:30:00    UCSanDiego@CalStateDomHills        142.4
# ...

# %%
plt.figure(figsize=(80,80))
df_19_20.plot(x="Opponent", y=["OPP_PPP","UCSD_PPP"], kind="bar",width=.5,color=['Blue','Gold'])
plt.xlabel("Opponent"),plt.ylabel('Pts Per 100 Pos'),plt.title("2019-2020 Season")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
# plt.subplot(x='Last',y=["AST","TS%","TPo%"])
plt.savefig('PPP_PerOpp2019.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %% [markdown]
# - I want to make a dataframe that stores the teams who hold us below our average Points per possesion this season

# %%
df_below_APPP = df_19_20.loc[df_19_20['UCSD_PPP_Adj']<1.23].sort_values(by=['UCSD_PPP_Adj'])

# %%
df_below_APPP
# Out:
#                   Date                      Game Name  AwayTeamPPP  \
# 10 2020-12-22 14:30:00       UCSanDiego@CalPolyPomona         95.7
# 0  2020-02-01 20:00:00  CalStateStanislaus@UCSanDiego         92.4
# 8  2020-01-04 18:30:00     CalStateEastBay@UCSanDiego        101.4
# 13 2020-12-05 18:30:00               Chico@UCSanDiego        119.1
# 7  2020-01-09 18:30:00  UCSanDiego@CalStateStanislaus        107.2
# 5  2020-01-16 18:30:00       CalPolyPomona@UCSanDiego         95.0
# 16 2020-11-24 14:00:00     UCSanDiego@CSSanBernardino        116.2
# 20 2020-11-09 18:30:00         UCSanDiego@WesternWash        116.9
# 3  2020-01-23 18:30:00      UCSanDiego@SanFranciscoSt        119.1
# 4  2020-01-18 18:30:00     CSSanBernardino@UCSanDiego         81.9
#
#     HomeTeamPPP  AwayScore  HomeScore  UCSD Season PPP  Wins  Losses  \
# 10         81.2         66         56             1.23     1       0
# 0         103.9         73         80             1.23     1       0
# ...

# %%
# plt.figure(figsize=(80,80))
# df_below_APPP.plot(x="Game Name", y=['UCSD Pts','UCSD_POSS','Opp Pts','OPP_POSS'], kind="bar",width=.5,color=['Blue','Gold','Black','Red'])
# plt.xlabel("Opponent"),plt.ylabel('Pts Per 100 Pos'),plt.title("2019-2020 Season")
# lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))

# %%
plt.figure(figsize=(80,80))
df_below_APPP.plot(x="Opponent", y=["OPP_PPP_Adj","UCSD_PPP_Adj"], kind="bar",width=.5,color=['Gold','Blue'])
plt.xlabel("Opponent"),plt.ylabel('Pts Per Possesion'),plt.title("2019-2020 Season")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))

# %%
plt.figure(figsize=(80,80))
df_below_APPP.plot(x="Opponent", y=["Opp Pts","UCSD Pts"], kind="bar",width=.5,color=['Gold','Blue'])
plt.xlabel("Opponent"),plt.ylabel('Points'),plt.title("2019-2020 Season")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))

# %%
data = {'Season':['17-18', '18-19', '19-20'], 'Average PPP':[100*0.96, 100*1.033, 100*1.23],'OPP Average PPP':[100*0.9125,100*0.886,96.1], 'Wins':[21,26,21], 'Losses':[11,8,1]
       , 'Won CCAA Tournament':['Yes','Yes','TBD']} 
df_seasons_ppp = pd.DataFrame(data)
df_seasons_ppp
# Out:
#   Season  Average PPP  OPP Average PPP  Wins  Losses Won CCAA Tournament
# 0  17-18         96.0            91.25    21      11                 Yes
# 1  18-19        103.3            88.60    26       8                 Yes
# 2  19-20        123.0            96.10    21       1                 TBD

# %%
ax = df_seasons_ppp.plot(x='Season', y=['Average PPP','OPP Average PPP'], kind="bar",width=.5,color=['Gold','Blue'])
plt.xlabel("Season"),plt.ylabel('Points Per 100 Possesion'),plt.title("From 2017-2020 Seasons")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.007))
plt.savefig('PPP_seasons.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=130)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-d3e3f1af0471> in <module>
#       2     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
#       3
# ----> 4 ax.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
plt.figure(figsize=(80,80))
ax = df_seasons_ppp.plot(x='Season', y=['Wins','Losses'], kind="bar",width=.5,color=['Gold','Blue'])
plt.xlabel("Season"),plt.ylabel(''),plt.title("Season Win-Loss Record")
lgd = plt.legend(loc='upper left', bbox_to_anchor=(1,1))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.007))
plt.savefig('PPP_seasonswins.png',bbox_extra_artists=(lgd,),bbox_inches='tight',dpi=120)

# %% [markdown]
# - The first bar chart presented has UCSD men's basketball "points per possesion" in the hello bars which has been adjusted to be points per 100 possesions for the sake of making the graphs easier to read and interpret. The

# %%
pearsoncorr_seas=df_19_20.corr(method='pearson')

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(pearsoncorr_seas, 
            xticklabels=pearsoncorr_seas.columns,
            yticklabels=pearsoncorr_seas.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show() # ta-da!

# %%
df_19_20.plot.scatter(y='Wins',x='UCSD_PPP_Adj',c='DarkBlue')

# %%
# I need to import some more statistical packages to use in determing the distribution 
from sklearn.linear_model import LinearRegression

# %%
df_19_20
# Out:
#                   Date                      Game Name  AwayTeamPPP  \
# 0  2020-02-01 20:00:00  CalStateStanislaus@UCSanDiego         92.4
# 1  2020-01-30 18:30:00       HumboldtState@UCSanDiego         91.3
# 2  2020-01-25 14:00:00         UCSanDiego@SonomaState        133.3
# 3  2020-01-23 18:30:00      UCSanDiego@SanFranciscoSt        119.1
# 4  2020-01-18 18:30:00     CSSanBernardino@UCSanDiego         81.9
# 5  2020-01-16 18:30:00       CalPolyPomona@UCSanDiego         95.0
# 6  2020-01-11 18:30:00       UCSanDiego@HumboldtState        132.3
# 7  2020-01-09 18:30:00  UCSanDiego@CalStateStanislaus        107.2
# 8  2020-01-04 18:30:00     CalStateEastBay@UCSanDiego        101.4
# 9  2020-01-02 18:30:00          CSMonterey@UCSanDiego        102.9
# 10 2020-12-22 14:30:00       UCSanDiego@CalPolyPomona         95.7
# 11 2020-12-19 18:30:00         SonomaState@UCSanDiego        109.5
# 12 2020-12-17 18:30:00    UCSanDiego@CalStateDomHills        142.4
# ...

# %%
data = df_19_20  # load data set
X = data['UCSD_PPP_Adj'].values.reshape(-1, 1)  # values converts it into a numpy array
Y = data['Wins'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
feature_cols = ['UCSD_PPP_Adj','OPP_PPP_Adj',]
X = data[feature_cols] # Features
y = data.Wins # Target variable

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
# from sklearn.linear_model import LogisticRegression

# # instantiate the model (using the default parameters)
# logreg = LogisticRegression()

# # fit the model with data
# logreg.fit(X_train,y_train)

# #
# y_pred=logreg.predict(X_test)

X = X.astype('int')
Y = y.astype('int')

logreg = LogisticRegression()

for i in range(len(X)):
    if i in range (0,3): 
        continue
        logreg.fit(X[:i], Y[:i])
